# %%
import warnings

warnings.filterwarnings('ignore')

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %matplotlib inline

# %%
data = pd.read_csv('dataset.csv')

# %%
dataset = data

# %%
data.shape
# Out:
# (1825, 11)

# %%
terms = ['Nav', 'VGSC', 'Cav', 'Kav', 'HCN', 'insecticidal', 
         'Paralytic', 'neurotoxic', 'KCav', 'nAChR', 'AChE', 
         'ion channel', 'CHRM', 'HCN', 'noxious']

all = []
for i in terms:

    categories = data[data['ShortFunction'].str.contains(i)]
    count = categories.shape[0]
    all.append(count)

# %%
plt.bar(terms, all)

plt.xticks(rotation=45, ha='right')
plt.show()

# %%
terms = ['Nav', 'VGSC', 'Cav', 'Kav', 'HCN', 
         'Paralytic', 'neurotoxic', 'KCav', 'nAChR', 'AChE', 
         'ion channel', 'CHRM', 'HCN']

for t in terms:
    for i in range(len(data)):
        if t in dataset.ShortFunction[i]:
            dataset.ShortFunction[i] = 'neurotoxic'

neurotx = dataset[dataset['ShortFunction'] == 'neurotoxic'].shape[0]
insecticidal = dataset[dataset['ShortFunction'].str.contains('insecticidal')].shape[0]
toxic = data[dataset['ShortFunction'].str.contains('noxious')].shape[0]

# %%
labels = ['neurotoxic', 'insecticidal', 'toxic to insects']
prop = [neurotx, insecticidal, toxic]
print(prop)
# Out:
# [1715, 102, 8]

# %%
colors = ['#0000FF', '#ADFF2F', '#FFA500']

# explosion
explode = (0.05, 0.05, 0.05)
 
# Pie Chart
fig, ax = fig, ax = plt.subplots(figsize=(12, 6))

ax.pie(prop, colors=colors, labels=labels,
        autopct='%1.1f%%', pctdistance=0.85)

# draw circle
centre_circle = plt.Circle((0, 0), 0.60, fc='white')
plot = plt.gcf()
 
# Adding Circle in Pie chart
plot.gca().add_artist(centre_circle)

# Adding Title of chart
plt.title('Categorical distinct peptides')

plt.show()

# %%
neurotx = data[data['ShortFunctio

# %% [markdown]
# ## Voltage-gated Sodium Channel Inhibitors

# %%
vgsc = data[data['ShortFunction'].str.contains('VGSC', na=False)]
