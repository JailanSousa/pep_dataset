# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %matplotlib inline
# Out:
# /tmp/ipykernel_3123/791146372.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = pd.read_csv('dataset.csv')

# %%
data.shape
# Out:
# (1755, 11)

# %%
def count(term):

    categories = data[data['ShortFunction'].str.contains(term)]
    quant = categories.shape[0]
    return quant

# %%
terms = ['Nav', 'VGSC', 'Cav', 'Kav', 'HCN', 'insecticidal', 
         'Paralytic', 'neurotoxic', 'KCav', 'nAChR', 'AChE', 
         'ion channel', 'CHRM', 'toxic']

all, neurotx = [], []
insecticidal, toxic = '', ''
for i in terms:
    
    all.append(count(i))

    if i != 'insecticidal' and i != 'toxic':
        neurotx.append(count(i))

    elif i == 'insecticidal':
        insecticidal = count(i)

    else:
        toxic = count(i)

# %%
plt.bar(terms, all)

plt.xticks(rotation=45, ha='right')
plt.show()

# %%
labels = ['neurotoxic', 'insecticidal', 'toxix to insects']
prop = [sum(neurotx), insecticidal, toxic]

# %%
colors = ['#0000FF', '#ADFF2F', '#FFA500']

# explosion
explode = (0.05, 0.05, 0.05)
 
# Pie Chart
plt.pie(prop, colors=colors, labels=labels,
        autopct='%1.1f%%', pctdistance=0.85,
        explode=explode)
 
# draw circle
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
 
# Adding Circle in Pie chart
fig.gca().add_artist(centre_circle)
 
# Adding Title of chart
plt.title('Categorical distinct peptides')

plt.show()

# %% [markdown]
# ## Voltage-gated Sodium Channel Inhibitors

# %%
vgsc = data[data['ShortFunction'].str.contains('VGSC', na=False)]
